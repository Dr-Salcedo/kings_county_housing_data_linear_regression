# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.lat.describe()
# Out:
# count    21597.000000
# mean        47.560093
# std          0.138552
# min         47.155900
# 25%         47.471100
# 50%         47.571800
# 75%         47.678000
# max         47.777600
# Name: lat, dtype: float64

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
if df[df["bedrooms"]]==11:
    print(index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-d8b42cac4438> in <module>
#       1
# ----> 2 if df[df["bedrooms"]]==11:
#       3     print(index)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
df_lat.map(str).apply(len)
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5
# 12       5
# 13       5
# 14       5
# 15       5
# 16       5
# 17       5
# 18       5
# 19       5
# 20       5
# 21       5
# 22       5
# 23       5
# 24       5
# 25       5
# 26       5
# 27       5
# 28       5
# 29       5
#         ..
# 21567    5
# 21568    5
# 21569    5
# 21570    5
# 21571    5
# 21572    5
# 21573    5
# 21574    5
# 21575    5
# 21576    5
# 21577    5
# 21578    5
# 21579    5
# 21580    5
# 21581    5
# 21582    5
# 21583    5
# 21584    5
# 21585    5
# 21586    5
# 21587    5
# 21588    5
# 21589    5
# 21590    5
# 21591    5
# 21592    5
# 21593    5
# 21594    5
# 21595    5
# 21596    5
# Name: bedrooms, Length: 21597, dtype: int64

# %%
df.hist(figsize=(14,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c1976c080>,
# ...
#       dtype=object)

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols

# %%
df_int=int(df["sqft_basement"])

df_int = [list(map(int, x)) for x in df["sqft_basement"].map(list(x))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-05ff843aa415> in <module>
# ----> 1 df_int=int(df["sqft_basement"])
#       2
#       3 df_int = [list(map(int, x)) for x in df["sqft_basement"].map(list(x))]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df_regression=['bathrooms', 'bedrooms', 'sqft_above', 'sqft_lot', 'floors', 'grade', 'sqft_living15', 'sqft_lot15']
df_added=" + ".join(df_regression)

# %%
df_added
# Out:
# 'bathrooms + bedrooms + sqft_above + sqft_lot + floors + grade + sqft_living15 + sqft_lot15'

# %%
f = 'price~' + df_added

# %%
f
# Out:
# 'price~bathrooms + bedrooms + sqft_above + sqft_lot + floors + grade + sqft_living15 + sqft_lot15'

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.sqft_basement
# Out:
# 0           0.0
# 1         400.0
# 2           0.0
# 3         910.0
# 4           0.0
# 5        1530.0
# 6             ?
# 7           0.0
# 8         730.0
# 9           0.0
# 10       1700.0
# 11        300.0
# 12          0.0
# 13          0.0
# 14          0.0
# 15        970.0
# 16          0.0
# 17          0.0
# 18            ?
# 19          0.0
# 20        760.0
# 21        720.0
# 22          0.0
# 23          0.0
# 24          0.0
# 25          0.0
# 26        700.0
# 27          0.0
# 28        730.0
# 29          0.0
#           ...
# 21567       0.0
# 21568     320.0
# 21569       0.0
# 21570       0.0
# 21571       0.0
# 21572     190.0
# 21573       0.0
# 21574    1800.0
# 21575       0.0
# 21576       0.0
# 21577       0.0
# 21578       0.0
# 21579      50.0
# 21580       0.0
# 21581         ?
# 21582       0.0
# 21583       0.0
# 21584       0.0
# 21585       0.0
# 21586       0.0
# 21587       0.0
# 21588       0.0
# 21589       0.0
# 21590     910.0
# ...

# %%
model = smf.ols(formula=f, data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.494
# Model:                            OLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                     2639.
# Date:                Mon, 06 May 2019   Prob (F-statistic):               0.00
# Time:                        15:14:09   Log-Likelihood:            -3.0002e+05
# No. Observations:               21597   AIC:                         6.001e+05
# Df Residuals:                   21588   BIC:                         6.001e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
import seaborn as sns

corr = df.corr()
plt.figure(figsize=(20,10))
sns.set_context("paper", font_scale=2)
plt.title('Heat Map')
sns.heatmap(corr, annot=True, annot_kws={"size": 7})
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
sns.heatmap(df.corr(),annot=False, linewidth=.5, cmap="coolwarm")

# %%
# create a DataFrame with the minimum and maximum values of TV
X_new = pd.df({'TV': [data.df_added.min(), data.df_added.max()]})
print(X_new.head())

# make predictions for those x values and store them
preds = model.predict(X_new)
print (preds)

# first, plot the observed data and the least squares line
data.plot(kind='scatter', x=df_added, y='price')
plt.plot(X_new, preds, c='red', linewidth=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-205-b1b798c25311> in <module>
#       1 # create a DataFrame with the minimum and maximum values of TV
# ----> 2 X_new = pd.df({'TV': [data.df_added.min(), data.df_added.max()]})
#       3 print(X_new.head())
#       4
#       5 # make predictions for those x values and store them
#
# AttributeError: module 'pandas' has no attribute 'df'

# %%
regr = linear_model.LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-06556c22c606> in <module>
# ----> 1 regr = linear_model.LinearRegression()
#
# NameError: name 'linear_model' is not defined
